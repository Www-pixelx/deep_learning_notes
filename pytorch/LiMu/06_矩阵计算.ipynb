# %%
import torch

# %% [markdown]
# (1)标量对向量求导
# ![屏幕截图 2025-07-21 104647.png](attachment:add5c34e-65cc-474a-91b7-cb7a6f7a182b.png)
#
# (2)向量对标量求导
# ![屏幕截图 2025-07-21 105323.png](attachment:18feb627-eab3-4a33-b3f6-3d5f69ca91ff.png)
#
# (3)向量对向量求导
# ![屏幕截图 2025-07-21 105509.png](attachment:8e05756c-4db7-42d7-a2a7-07bb857694e8.png)
